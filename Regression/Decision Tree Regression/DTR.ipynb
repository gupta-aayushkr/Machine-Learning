# %% [markdown]
# Decision Tree Regreesion StatsQuest Theory - https://www.youtube.com/watch?v=g9c66TUylZ4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
print(y)
regressor.predict(X)
# Out:
# [  45000   50000   60000   80000  110000  150000  200000  300000  500000
#  1000000]
# array([  45000.,   50000.,   60000.,   80000.,  110000.,  150000.,
#         200000.,  300000.,  500000., 1000000.])

# %%
plt.scatter(X,y, color='red')
plt.plot(X, regressor.predict(X), color='blue')
plt.title('Polinomial Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# IN the Tutorial he has increased the data points on x axis therefore this prediction looks skewed according to me

# %%
plt.scatter(X,y, color='red')
X_grid = np.arange(min(X), max(X), 0.1)  #creating more data points on X-axis
X_grid = X_grid.reshape(len(X_grid),1) #trandorming array in 2D matrix with only one col and many rows
plt.plot(X_grid, regressor.predict(X_grid), color='blue') #using X_grid for prediction
plt.title('Polinomial Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# /var/folders/0h/1ykftl_53n5gzxr93wfqj35c0000gn/T/ipykernel_7971/2960831524.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)  #creating more data points on X-axis
