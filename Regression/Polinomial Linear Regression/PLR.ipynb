# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
#poly reg will contain values of x, x sqaured, x cube and so on
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
#we have to noew send this matrix of feature to the polinomial regression
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y, color='red')
plt.plot(X, lin_reg.predict(poly_reg.fit_transform(X)), color='blue')
plt.title('Polinomial Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# A Person with Experience Level of 6.5 will have what salary

# %%
lin_reg.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265152])
